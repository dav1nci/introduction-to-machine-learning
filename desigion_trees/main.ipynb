# %%
# %matplotlib inline
import numpy as np
from sklearn.tree import DecisionTreeClassifier
import pandas

data = pandas.read_csv('titanic.csv', index_col='PassengerId')
X = data[['Fare', 'Pclass', 'Age', 'Sex', 'Survived']].dropna(axis=0).as_matrix()
X[X[:, 3] == 'female', 3] = 0
X[X[:, 3] == 'male', 3] = 1
survived = X[:, 4].astype(np.int64)
X = np.delete(X, [4], axis=1)



clf = DecisionTreeClassifier(random_state=241)
clf.fit(X, survived)
clf.feature_importances_
# Out:
# array([ 0.30644165,  0.13700004,  0.2560461 ,  0.30051221])

# %%
X = data[['Pclass', 'Fare', 'Age', 'Sex', 'Survived']].dropna(axis=0).as_matrix()
X[X[:, 3] == 'female', 3] = 0
X[X[:, 3] == 'male', 3] = 1
print X
print X[3]
data[['Pclass', 'Fare', 'Age', 'Sex', 'Survived']].dropna(axis=0)
# Out:
# [[3 7.25 22.0 1 0]
#  [1 71.2833 38.0 0 1]
#  [3 7.925 26.0 0 1]
#  ...,
#  [1 30.0 19.0 0 1]
#  [1 30.0 26.0 1 1]
#  [3 7.75 32.0 1 0]]
# [1 53.1 35.0 0 1]
#              Pclass      Fare   Age     Sex  Survived
# PassengerId
# 1                 3    7.2500  22.0    male         0
# 2                 1   71.2833  38.0  female         1
# 3                 3    7.9250  26.0  female         1
# 4                 1   53.1000  35.0  female         1
# 5                 3    8.0500  35.0    male         0
# 7                 1   51.8625  54.0    male         0
# 8                 3   21.0750   2.0    male         0
# 9                 3   11.1333  27.0  female         1
# 10                2   30.0708  14.0  female         1
# 11                3   16.7000   4.0  female         1
# 12                1   26.5500  58.0  female         1
# 13                3    8.0500  20.0    male         0
# 14                3   31.2750  39.0    male         0
# ...
